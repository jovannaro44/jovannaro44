# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user' 
df = pd.read_csv(url,sep = '|')
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
df.groupby('occupation')['age'].mean()
df.loc[:,('age','occupation')].groupby('occupation').mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
def convert_gender_male_1(x):
    if (x =='M'):
        return(1)
    else:
        return(0)
    
#convert_gender_male_1('M')
#convert_gender_male_1('F')
df.gender = df.gender.apply(convert_gender_male_1)
df.head()
# Out:
#    user_id  age  gender  occupation zip_code
# 0        1   24       1  technician    85711
# 1        2   53       0       other    94043
# 2        3   23       1      writer    32067
# 3        4   24       1  technician    43537
# 4        5   33       0       other    15213

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
(df.groupby('occupation').gender.mean()*100).sort_values(ascending=False)
df.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
df.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  0         40.638889
#                1         37.162791
# artist         0         30.307692
#                1         32.333333
# doctor         1         43.571429
# educator       0         39.115385
#                1         43.101449
# engineer       0         29.500000
#                1         36.600000
# entertainment  0         31.000000
#                1         29.000000
# executive      0         44.000000
#                1         38.172414
# healthcare     0         39.818182
#                1         45.400000
# homemaker      0         34.166667
#                1         23.000000
# lawyer         0         39.500000
#                1         36.200000
# librarian      0         40.000000
#                1         40.000000
# marketing      0         37.200000
#                1         37.875000
# none           0         36.500000
#                1         18.600000
# other          0         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men
